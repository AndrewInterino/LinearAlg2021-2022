# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewInterino/LinearAlg2021-2022/blob/main/FinalAssignment_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![lab10.png](data:image/png;base64,...)

# %% [markdown]
# ## Laboratory 10 : Linear Combination and Vector Spaces

# %% [markdown]
# ### Objectives
# At the end of this activity you will be able to:
# 1. Be familiar with representing linear combinations in the 2-dimensional plane.
# 2. Visualize spans using vector fields in Python.
# 3. Perform vector fields operations using scientific programming.

# %% [markdown]
# #Discussion

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Linear Combination

# %% [markdown]
# It is said that a linear combination is the combination of linear scaling and addition of a vector its bases/components
#
# We will try to visualize the vectors and their linear combinations by plotting a sample of real number values for the scalars for the vectors. Let's first try the vectors below:

# %% [markdown]
# $$X = \begin{bmatrix} 2\\5 \\\end{bmatrix} , Y = \begin{bmatrix} 7\\9 \\\end{bmatrix} $$

# %%
vectX = np.array([2,5])
vectY = np.array([7,9])
vectY
# Out:
# array([7, 9])

# %% [markdown]
# ### Span of Single vectors

# %% [markdown]
# As discussed in the lecture, the span of individual vectors can be represented by a line span. Let's take vector $X$ as an example.

# %% [markdown]
# $$X = c\cdot \begin{bmatrix} 2\\5 \\\end{bmatrix} $$

# %%
c = np.arange(-10,10,0.125)
plt.scatter(c*vectX[0],c*vectX[1])

plt.xlim(-10,10)
plt.ylim(-10,10)
plt.axhline(y=0,color='k')
plt.axvline(x=0,color='k')
plt.grid()
plt.show()

# %%
c = np.arange(-15,15,0.5)
plt.scatter(c*vectX[0],c*vectX[1])

plt.xlim(-10,10)
plt.ylim(-10,10)
plt.axhline(y=0,color='k')
plt.axvline(x=0,color='k')
plt.grid()
plt.show()

# %% [markdown]
# ### Span of linear combination of vector

# %% [markdown]
# So what if we are to plot the span of a linear combination of vectors? We can visualize as a plane on the 2-dimensional coordinate system. Let's take the span of the linear combination below:

# %% [markdown]
# $$S = \begin{Bmatrix} c_1 \cdot\begin{bmatrix} 1\\0 \\\end{bmatrix},
# c_2 \cdot \begin{bmatrix} 1\\-1 \\\end{bmatrix}\end{Bmatrix} $$

# %%
vectA = np.array([1,0])
vectB = np.array([1,-1])

R= np.arange(-10,10,1)

c1,c2 = np.meshgrid(R,R)
vectR = vectA + vectB
spanRx = c1*vectA[0]+c2*vectB[1]
spanRy = c1*vectA[1]+c2*vectB[0]
plt.scatter(spanRx,spanRy, s=5,alpha=0.75)
#plt.scatter(R*vectA[0],R*vectA[1])

plt.axhline(y=0,color='k')
plt.axvline(x=0,color='k')
plt.grid()
plt.show()

# %%
vectP = np.array([2,1])
vectQ = np.array([4,3])

R= np.arange(-10,10,1)

c1,c2 = np.meshgrid(R,R)
vectR = vectP + vectQ
spanRx = c1*vectP[0]+c2*vectQ[1]
spanRy = c1*vectP[1]+c2*vectQ[0]
plt.scatter(spanRx,spanRy, s=5,alpha=0.75)
#plt.scatter(R*vectA[0],R*vectA[1])

plt.axhline(y=0,color='k')
plt.axvline(x=0,color='k')
plt.grid()
plt.show()

# %% [markdown]
# # Activity

# %% [markdown]
# Try different linear combinations using different scalar values. In your methodology discuss the different functions that you have used, the  linear equation and vector form of the linear combination, and the flowchart for declaring and displaying linear combinations. Please make sure that your flowchart has only few words and not putting the entire code as it is bad practice. In your results, display and discuss the linear combination visualization you made. You should use the cells below for displaying the equation markdows using LaTeX and your code.

# %%
vectH = np.array([-2,2])
vectI = np.array([2,2])

R= np.arange(-30,30,1)

c1,c2 = np.meshgrid(R,R)
vectR = vectH + vectI
spanRx = c1*vectH[0]+c2*vectI[1]
spanRy = c1*vectH[1]+c2*vectI[0]
plt.scatter(spanRx,spanRy, s=5,alpha=0.75)

plt.axhline(y=0,color='k')
plt.axvline(x=0,color='k')
plt.grid()
plt.show()

# %% [markdown]
# Methodology:
# the scalar vectors that I use which are both the same value to result an equal shaped plane. Meaning, both of my scalar vector variable has a value of 2 each except for the vectH having (-2,2) for the plane to shape as a diamond. As for the range, which ranges up to 30 and -30 in order to give a wider view of the plane but slightly compressed because of the limitation of Google colab. The Scatter that which increase then compressed making look more solid.

# %% [markdown]
# ![flowchart10.png](data:image/png;base64,...)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Based on this experiment, I learned the application of scalar vectors in formulating 2D planes with complex programming of Google colab. in linear combination, similar in assigning variable with array but this varaible need two values for it to be a scalar vector. as for the Span, this are the length of the line of the vector in the graph. So in apply linear combination in engineering, we can use this program in such design of a 2D plane or even lines that can help us shape certain scalar vectors.
